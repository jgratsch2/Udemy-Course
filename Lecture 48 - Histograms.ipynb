# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  8.,   5.,  21.,  15.,  19.,  14.,   9.,   5.,   2.,   2.]),
#  array([-2.102751 , -1.6026643, -1.1025776, -0.6024909, -0.1024042,
#          0.3976825,  0.8977692,  1.3978559,  1.8979426,  2.3980293,
#          2.898116 ]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color = 'indianred')
# Out:
# (array([  5.,   4.,   6.,  13.,  10.,  16.,  13.,   6.,   3.,   4.]),
#  array([-1.984306  , -1.58201399, -1.17972198, -0.77742997, -0.37513797,
#          0.02715404,  0.42944605,  0.83173806,  1.23403007,  1.63632207,
#          2.03861408]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed = True, color = 'indianred',alpha=0.5, bins = 20)
plt.hist(dataset2,normed = True, alpha = 0.5, bins = 20)
# Out:
# (array([ 0.12428783,  0.18643174,  0.06214391,  0.18643174,  0.12428783,
#          0.24857566,  0.37286348,  0.4350074 ,  0.37286348,  0.24857566,
#          0.49715131,  0.49715131,  0.55929523,  0.24857566,  0.12428783,
#          0.24857566,  0.18643174,  0.        ,  0.12428783,  0.12428783]),
#  array([-1.984306  , -1.78315999, -1.58201399, -1.38086799, -1.17972198,
#         -0.97857598, -0.77742997, -0.57628397, -0.37513797, -0.17399196,
#          0.02715404,  0.22830005,  0.42944605,  0.63059205,  0.83173806,
#          1.03288406,  1.23403007,  1.43517607,  1.63632207,  1.83746808,
#          2.03861408]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2, kind = 'hex')
