# %%
#for analysis
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

#for visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
import requests

# %%
from io import StringIO

# %%
url = 'http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.csv'

# %%
source = requests.get(url).text

# %%
poll_data = StringIO(source)

# %%
poll_df = pd.read_csv(poll_data)

# %%
poll_df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                    1000  Likely Voters       Live Phone     47      47
# 1                     740  Likely Voters         Internet     49      47
# 2                     872  Likely Voters  Automated Phone     48      48
# 3                     712  Likely Voters       Live Phone     50      49
# 4                    1500  Likely Voters  Automated Phone     48      49
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
poll_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590 entries, 0 to 589
# Data columns (total 17 columns):
# Pollster                  590 non-null object
# Start Date                590 non-null object
# End Date                  590 non-null object
# Entry Date/Time (ET)      590 non-null object
# Number of Observations    568 non-null float64
# Population                590 non-null object
# Mode                      590 non-null object
# Obama                     590 non-null float64
# Romney                    590 non-null float64
# Undecided                 423 non-null float64
# Other                     202 non-null float64
# Pollster URL              590 non-null object
# Source URL                588 non-null object
# Partisan                  590 non-null object
# Affiliation               590 non-null object
# Question Text             0 non-null float64
# Question Iteration        590 non-null int64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 83.0+ KB

# %%
poll_df.describe()
# Out:
#        Number of Observations       Obama      Romney   Undecided       Other  \
# count              568.000000  590.000000  590.000000  423.000000  202.000000
# mean              1295.390845   46.774576   44.572881    6.546099    3.400990
# std               1616.240271    2.447069    2.925320    3.698614    2.721318
# min                328.000000   37.000000   32.000000    1.000000    0.000000
# 25%                855.750000   45.000000   43.000000    4.000000    2.000000
# 50%               1000.000000   47.000000   45.000000    6.000000    3.000000
# 75%               1500.000000   48.000000   46.000000    8.000000    4.000000
# max              36472.000000   54.000000   53.000000   28.000000   19.000000
#
#        Question Text  Question Iteration
# count              0                 590
# mean             NaN                   1
# std              NaN                   0
# min              NaN                   1
# 25%              NaN                   1
# ...

# %%
np.unique(poll_df['Pollster'])
# Out:
# array(['ABC/Post', 'AP-GfK', 'ARG', 'Allstate/National Journal',
#        'Angus-Reid', 'Bloomberg', 'CBS', 'CBS/Times', 'CNN', 'Clarus',
#        'DailyKos/SEIU/PPP (D)', 'Democracy Corps (D)',
#        "Democracy Corps (D)/Campaign For America's Future",
#        "Democracy Corps (D)/Campaign for America's Future",
#        'Democracy Corps (D)/Center for American Progress',
#        "Democracy Corps (D)/Women's Voices. Women Vote.",
#        'Esquire/Yahoo! News', 'FOX', 'Fairleigh Dickinson',
#        'GWU/Politico (Lake/Tarrance)', 'Gallup', 'Gravis Marketing',
#        'High Point University', 'IBD/TIPP', 'Ipsos/Reuters',
#        'Ipsos/Reuters (Web)', 'JZ Analytics', 'JZ Analytics/Newsmax',
#        'Marist/McClatchy', 'Mason-Dixon',
#        'McLaughlin (R-American Conservative Union)', 'Merriman',
#        'Monmouth', 'NBC/WSJ', 'NPR', 'Newsweek/Daily Beast', 'PPP (D)',
#        'PPP (D-Americans United for Change)', 'Pew',
# ...

# %%
sns.factorplot(x='Affiliation',data=poll_df,kind='count')

# %%
sns.factorplot('Affiliation',data=poll_df,hue='Population', kind='count')

# %%
poll_df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                    1000  Likely Voters       Live Phone     47      47
# 1                     740  Likely Voters         Internet     49      47
# 2                     872  Likely Voters  Automated Phone     48      48
# 3                     712  Likely Voters       Live Phone     50      49
# 4                    1500  Likely Voters  Automated Phone     48      49
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
avg = pd.DataFrame(poll_df.mean())

avg.drop('Number of Observations', axis=0, inplace=True)
avg.drop('Other', axis=0, inplace =True)
avg.drop('Question Text', axis=0, inplace =True)
avg.drop('Question Iteration',axis=0, inplace=True)

# %%
avg.head()
# Out:
#                    0
# Obama      46.774576
# Romney     44.572881
# Undecided   6.546099

# %%
std = pd.DataFrame(poll_df.std())
std.drop('Number of Observations', axis=0, inplace =True)
std.drop('Other', axis=0, inplace =True)
std.drop('Question Iteration', axis=0, inplace =True)
std.drop('Question Text',axis=0,inplace=True)

# %%
std.head()
# Out:
#                   0
# Obama      2.447069
# Romney     2.925320
# Undecided  3.698614

# %%
avg.plot(yerr=std,kind='bar',legend=False)

# %%
poll_avg=pd.concat([avg,std],axis=1)

# %%
poll_avg.columns = ['Average', 'Standard Deviation']

# %%
poll_avg
# Out:
#              Average  Standard Deviation
# Obama      46.774576            2.447069
# Romney     44.572881            2.925320
# Undecided   6.546099            3.698614

# %%
poll_df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                    1000  Likely Voters       Live Phone     47      47
# 1                     740  Likely Voters         Internet     49      47
# 2                     872  Likely Voters  Automated Phone     48      48
# 3                     712  Likely Voters       Live Phone     50      49
# 4                    1500  Likely Voters  Automated Phone     48      49
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
poll_df.plot(x='End Date', y=['Obama','Romney', 'Undecided'], linestyle ='', marker='o' )

# %%
from datetime import datetime

# %%
poll_df['Difference'] = (poll_df.Obama - poll_df.Romney)/100

poll_df.head()
# Out:
#                     Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Politico/GWU/Battleground  2012-11-04  2012-11-05  2012-11-06T08:40:26Z
# 1           YouGov/Economist  2012-11-03  2012-11-05  2012-11-26T15:31:23Z
# 2           Gravis Marketing  2012-11-03  2012-11-05  2012-11-06T09:22:02Z
# 3                   IBD/TIPP  2012-11-03  2012-11-05  2012-11-06T08:51:48Z
# 4                  Rasmussen  2012-11-03  2012-11-05  2012-11-06T08:47:50Z
#
#    Number of Observations     Population             Mode  Obama  Romney  \
# 0                    1000  Likely Voters       Live Phone     47      47
# 1                     740  Likely Voters         Internet     49      47
# 2                     872  Likely Voters  Automated Phone     48      48
# 3                     712  Likely Voters       Live Phone     50      49
# 4                    1500  Likely Voters  Automated Phone     48      49
#
#    Undecided  Other                                       Pollster URL  \
# ...

# %%
poll_df = poll_df.groupby(['Start Date'], as_index=False).mean()

poll_df['Obama_positive'] = poll_df.Difference[poll_df.Difference >0]

# %%
poll_df.head()
# Out:
#    Start Date  Number of Observations  Obama  Romney  Undecided  Other  \
# 0  2009-03-13                    1403     44      44         12    NaN
# 1  2009-04-17                     686     50      39         11    NaN
# 2  2009-05-14                    1000     53      35         12    NaN
# 3  2009-06-12                     638     48      40         12    NaN
# 4  2009-07-15                     577     49      40         11    NaN
#
#    Question Text  Question Iteration  Difference  Obama_positive
# 0            NaN                   1        0.00             NaN
# 1            NaN                   1        0.11            0.11
# 2            NaN                   1        0.18            0.18
# 3            NaN                   1        0.08            0.08
# 4            NaN                   1        0.09            0.09

# %%
poll_df.plot('Start Date', ['Difference', 'Obama_positive'], figsize=(12,4), marker='o',linestyle='-', color = ['blue','red'])

# %%
row_in=0
xlimit = []

for date in poll_df['Start Date']:
    if date[0:7] == '2012-10':
        xlimit.append(row_in)
        row_in += 1
    else:
        row_in += 1

print(min(xlimit))
print(max(xlimit))
# Out:
# 329
# 356

# %%
poll_df.plot('Start Date', ['Difference', 'Obama_positive'], figsize=(12,4), marker='o',linestyle='-',
             color = ['blue','red'], xlim=(329,356))

#Oct 3rd
plt.axvline(x=329+2, linewidth = 4, color = 'grey')

#Oct 11th
plt.axvline(x=329+10, linewidth = 4, color = 'grey')

#Oct 22nd
plt.axvline(x=329+21, linewidth = 4, color = 'grey')

# %%
#Begin donations analysis

# %%
donor_df = pd.read_csv('Election_Donor_Data.csv')
# Out:
# C:\Users\joshg\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2902: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
donor_df.head()
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
#
#           contbr_city contbr_st   contbr_zip        contbr_employer  \
# 0              MOBILE        AL   3.6601e+08                RETIRED
# 1              MOBILE        AL   3.6601e+08                RETIRED
# 2              LANETT        AL  3.68633e+08  INFORMATION REQUESTED
# 3             PIGGOTT        AR  7.24548e+08                   NONE
# 4  HOT SPRINGS NATION        AR  7.19016e+08                   NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                RETIRED                250        20-JUN-11          NaN
# ...

# %%
donor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001731 entries, 0 to 1001730
# Data columns (total 16 columns):
# cmte_id              1001731 non-null object
# cand_id              1001731 non-null object
# cand_nm              1001731 non-null object
# contbr_nm            1001731 non-null object
# contbr_city          1001712 non-null object
# contbr_st            1001727 non-null object
# contbr_zip           1001620 non-null object
# contbr_employer      988002 non-null object
# contbr_occupation    993301 non-null object
# contb_receipt_amt    1001731 non-null float64
# contb_receipt_dt     1001731 non-null object
# receipt_desc         14166 non-null object
# memo_cd              92482 non-null object
# memo_text            97770 non-null object
# form_tp              1001731 non-null object
# file_num             1001731 non-null int64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 129.9+ MB

# %%
donor_df['contb_receipt_amt'].value_counts()
# Out:
#  100.00     178188
#  50.00      137584
#  25.00      110345
#  250.00      91182
#  500.00      57984
#  2500.00     49005
#  35.00       37237
#  1000.00     36494
#  10.00       33986
#  200.00      27813
#  20.00       17565
#  15.00       16163
#  150.00      14600
#  75.00       13647
#  201.20      11718
#  30.00       11381
#  300.00      11204
#  20.12        9897
#  5.00         9024
#  40.00        5007
#  2000.00      4128
#  55.00        3760
#  1500.00      3705
#  3.00         3383
#  60.00        3084
#  400.00       3066
# -2500.00      2727
#  110.00       2554
#  125.00       2520
#  19.00        2474
#              ...
#  128.68          1
#  60.71           1
#  139.68          1
#  143.43          1
#  155.43          1
#  160.93          1
#  190.68          1
#  195.18          1
#  198.18          1
#  62.46           1
#  93.88           1
#  101.88          1
#  34.46           1
#  25.96           1
#  26.21           1
#  28.96           1
# ...

# %%
donor_df['contb_receipt_amt'][donor_df.contb_receipt_amt == -2500]
# Out:
# 1062      -2500
# 1270      -2500
# 1327      -2500
# 1508      -2500
# 1514      -2500
# 1875      -2500
# 1902      -2500
# 1903      -2500
# 1907      -2500
# 1987      -2500
# 1990      -2500
# 2107      -2500
# 3319      -2500
# 4498      -2500
# 4691      -2500
# 4774      -2500
# 5086      -2500
# 5210      -2500
# 5229      -2500
# 5235      -2500
# 5516      -2500
# 5753      -2500
# 5758      -2500
# 5781      -2500
# 6409      -2500
# 6868      -2500
# 6900      -2500
# 6901      -2500
# 6902      -2500
# 6910      -2500
#            ...
# 1001236   -2500
# 1001237   -2500
# 1001238   -2500
# 1001239   -2500
# 1001240   -2500
# 1001241   -2500
# 1001242   -2500
# 1001243   -2500
# 1001245   -2500
# 1001261   -2500
# 1001358   -2500
# 1001450   -2500
# 1001451   -2500
# 1001500   -2500
# 1001504   -2500
# 1001537   -2500
# 1001550   -2500
# 1001568   -2500
# 1001571   -2500
# 1001620   -2500
# 1001624   -2500
# 1001631   -2500
# 1001636   -2500
# 1001655   -2500
# ...

# %%
#filtering revisited
donor_df[(donor_df.contb_receipt_amt == -2500)]
# Out:
#            cmte_id    cand_id       cand_nm                     contbr_nm  \
# 1062     C00431171  P80003353  Romney, Mitt             THOMPSON, MICHAEL
# 1270     C00431171  P80003353  Romney, Mitt      LANIER, CLIFFORD MR. JR.
# 1327     C00431171  P80003353  Romney, Mitt         BURTON, ROBERT O. MR.
# 1508     C00431171  P80003353  Romney, Mitt             DOVE, REID B. MR.
# 1514     C00431171  P80003353  Romney, Mitt        NOLAN, JOHN A. MR. III
# 1875     C00431171  P80003353  Romney, Mitt        WINGATE, MONROE J. MR.
# 1902     C00431171  P80003353  Romney, Mitt                STOLESON, MARK
# 1903     C00431171  P80003353  Romney, Mitt             VANDERVOORT, GLEN
# 1907     C00431171  P80003353  Romney, Mitt                LESUEUR, DAVID
# 1987     C00431171  P80003353  Romney, Mitt            HANLEY, LEE T. MR.
# 1990     C00431171  P80003353  Romney, Mitt         HANLEY, NANCY R. MRS.
# 2107     C00431171  P80003353  Romney, Mitt      OSCARSON, ROBERT DON MR.
# ...

# %%
don_mean = donor_df['contb_receipt_amt'].mean()

don_std = donor_df['contb_receipt_amt'].std()

print('The average donation was %.2f with a std %.2f' %(don_mean,don_std))
# Out:
# The average donation was 298.24 with a std 3749.67

# %%
top_donor = donor_df['contb_receipt_amt'].copy()
top_donor.sort_values()
# Out:
# 114604     -30800.00
# 226986     -25800.00
# 101356      -7500.00
# 398429      -5500.00
# 250737      -5455.00
# 33821       -5414.31
# 908565      -5115.00
# 456649      -5000.00
# 574657      -5000.00
# 30513       -5000.00
# 562267      -5000.00
# 30584       -5000.00
# 86268       -5000.00
# 708920      -5000.00
# 665887      -5000.00
# 708899      -5000.00
# 708929      -5000.00
# 21172       -5000.00
# 21168       -5000.00
# 21167       -5000.00
# 262328      -5000.00
# 946875      -5000.00
# 7361        -5000.00
# 416403      -5000.00
# 21164       -5000.00
# 707945      -5000.00
# 615101      -5000.00
# 7973        -5000.00
# 54430       -5000.00
# 54434       -5000.00
#              ...
# 708022      10000.00
# 708898      10000.00
# 710177      10000.00
# 876244      10000.00
# 709608      10000.00
# 708919      10000.00
# 709739      10000.00
# 91145       10000.00
# 708138      10000.00
# 993178      10000.00
# 709813      10000.00
# 710730      10000.00
# ...

# %%
top_donor = top_donor[top_donor > 0]

top_donor.sort_values()
# Out:
# 335573          0.01
# 335407          0.01
# 335352          0.01
# 324596          0.01
# 329896          0.01
# 318560          0.01
# 335100          0.01
# 318670          0.01
# 329984          0.01
# 335087          0.01
# 335033          0.01
# 330220          0.01
# 330222          0.01
# 324283          0.01
# 324170          0.01
# 334913          0.01
# 334899          0.01
# 323823          0.01
# 324778          0.01
# 323822          0.01
# 324838          0.01
# 324876          0.01
# 336020          0.01
# 317634          0.01
# 325344          0.01
# 335767          0.01
# 317753          0.01
# 325153          0.01
# 325151          0.01
# 350626          0.01
#              ...
# 710177      10000.00
# 709608      10000.00
# 99829       10000.00
# 711167      10000.00
# 993178      10000.00
# 710198      10000.00
# 708928      10000.00
# 708022      10000.00
# 709739      10000.00
# 709859      10000.00
# 709813      10000.00
# 708919      10000.00
# ...

# %%
top_donor.value_counts().head(10)
# Out:
# 100     178188
# 50      137584
# 25      110345
# 250      91182
# 500      57984
# 2500     49005
# 35       37237
# 1000     36494
# 10       33986
# 200      27813
# Name: contb_receipt_amt, dtype: int64

# %%
com_don = top_donor[top_donor < 2500]

com_don.hist(bins=100)

# %%
candidate = donor_df.cand_nm.unique()

# %%
candidate
# Out:
# array(['Bachmann, Michelle', 'Romney, Mitt', 'Obama, Barack',
#        "Roemer, Charles E. 'Buddy' III", 'Pawlenty, Timothy',
#        'Johnson, Gary Earl', 'Paul, Ron', 'Santorum, Rick', 'Cain, Herman',
#        'Gingrich, Newt', 'McCotter, Thaddeus G', 'Huntsman, Jon',
#        'Perry, Rick'], dtype=object)

# %%
# Dictionary of party affiliation
party_map = {'Bachmann, Michelle': 'Republican',
           'Cain, Herman': 'Republican',
           'Gingrich, Newt': 'Republican',
           'Huntsman, Jon': 'Republican',
           'Johnson, Gary Earl': 'Republican',
           'McCotter, Thaddeus G': 'Republican',
           'Obama, Barack': 'Democrat',
           'Paul, Ron': 'Republican',
           'Pawlenty, Timothy': 'Republican',
           'Perry, Rick': 'Republican',
           "Roemer, Charles E. 'Buddy' III": 'Republican',
           'Romney, Mitt': 'Republican',
           'Santorum, Rick': 'Republican'}

donor_df['Party'] = donor_df.cand_nm.map(party_map)

# %%
donor_df = donor_df[donor_df.contb_receipt_amt > 0]

# %%
donor_df.head(200)
# Out:
#        cmte_id    cand_id             cand_nm            contbr_nm  \
# 0    C00410118  P20002978  Bachmann, Michelle      HARVEY, WILLIAM
# 1    C00410118  P20002978  Bachmann, Michelle      HARVEY, WILLIAM
# 2    C00410118  P20002978  Bachmann, Michelle        SMITH, LANIER
# 3    C00410118  P20002978  Bachmann, Michelle     BLEVINS, DARONDA
# 4    C00410118  P20002978  Bachmann, Michelle   WARDENBURG, HAROLD
# 5    C00410118  P20002978  Bachmann, Michelle       BECKMAN, JAMES
# 6    C00410118  P20002978  Bachmann, Michelle     BLEVINS, DARONDA
# 7    C00410118  P20002978  Bachmann, Michelle     BLEVINS, DARONDA
# 8    C00410118  P20002978  Bachmann, Michelle       COLLINS, SARAH
# 9    C00410118  P20002978  Bachmann, Michelle      COLEMAN, RONALD
# 10   C00410118  P20002978  Bachmann, Michelle   ATCHLEY, JR, KEITH
# 11   C00410118  P20002978  Bachmann, Michelle     FARNSWORTH, ROSS
# 12   C00410118  P20002978  Bachmann, Michelle    PRESTON, CLIFFORD
# ...

# %%
donor_df.groupby('cand_nm')['contb_receipt_amt'].count()
# Out:
# cand_nm
# Bachmann, Michelle                 13082
# Cain, Herman                       20052
# Gingrich, Newt                     46883
# Huntsman, Jon                       4066
# Johnson, Gary Earl                  1234
# McCotter, Thaddeus G                  73
# Obama, Barack                     589127
# Paul, Ron                         143161
# Pawlenty, Timothy                   3844
# Perry, Rick                        12709
# Roemer, Charles E. 'Buddy' III      5844
# Romney, Mitt                      105155
# Santorum, Rick                     46245
# Name: contb_receipt_amt, dtype: int64

# %%
donor_df.groupby('cand_nm')['contb_receipt_amt'].sum()
# Out:
# cand_nm
# Bachmann, Michelle                2.711439e+06
# Cain, Herman                      7.101082e+06
# Gingrich, Newt                    1.283277e+07
# Huntsman, Jon                     3.330373e+06
# Johnson, Gary Earl                5.669616e+05
# McCotter, Thaddeus G              3.903000e+04
# Obama, Barack                     1.358774e+08
# Paul, Ron                         2.100962e+07
# Pawlenty, Timothy                 6.004819e+06
# Perry, Rick                       2.030575e+07
# Roemer, Charles E. 'Buddy' III    3.730099e+05
# Romney, Mitt                      8.833591e+07
# Santorum, Rick                    1.104316e+07
# Name: contb_receipt_amt, dtype: float64

# %%
cand_amount = donor_df.groupby('cand_nm')['contb_receipt_amt'].sum()

i = 0
for don in cand_amount:
    print('The candidate %s raised %.0f dollars' %(cand_amount.index[i],don))
    print('\n')
    i+=1
# Out:
# The candidate Bachmann, Michelle raised 2711439 dollars
#
#
# The candidate Cain, Herman raised 7101082 dollars
#
#
# The candidate Gingrich, Newt raised 12832770 dollars
#
#
# The candidate Huntsman, Jon raised 3330373 dollars
#
#
# The candidate Johnson, Gary Earl raised 566962 dollars
#
#
# The candidate McCotter, Thaddeus G raised 39030 dollars
#
#
# The candidate Obama, Barack raised 135877427 dollars
#
#
# The candidate Paul, Ron raised 21009620 dollars
#
#
# The candidate Pawlenty, Timothy raised 6004819 dollars
#
#
# The candidate Perry, Rick raised 20305754 dollars
#
#
# The candidate Roemer, Charles E. 'Buddy' III raised 373010 dollars
#
#
# The candidate Romney, Mitt raised 88335908 dollars
#
#
# The candidate Santorum, Rick raised 11043159 dollars

# %%
cand_amount.plot(kind='bar')

# %%
donor_df.groupby('Party')['contb_receipt_amt'].sum().plot(kind='bar')

# %%
occupation_df = donor_df.pivot_table('contb_receipt_amt',
                                     index = 'contbr_occupation',
                                     columns = 'Party',
                                     aggfunc = 'sum')

# %%
occupation_df
# Out:
# Party                                  Democrat  Republican
# contbr_occupation
#    MIXED-MEDIA ARTIST / STORYTELLER         100         NaN
#  AREA VICE PRESIDENT                        250         NaN
#  RESEARCH ASSOCIATE                         100         NaN
#  TEACHER                                    500         NaN
#  THERAPIST                                 3900         NaN
# 'MIS MANAGER                                NaN      177.60
# (PART-TIME) SALES CONSULTANT & WRITER       NaN      285.00
# (RETIRED)                                   NaN      250.00
# -                                          5000     2114.80
# --                                          NaN       75.00
# .NET PROGRAMMER                             481         NaN
# 0                                           NaN       20.00
# 07/13/1972                                   98         NaN
# 100% DISABLED ARMY VET                      NaN      350.00
# ...

# %%
occupation_df.shape
# Out:
# (45067, 2)

# %%
occupation_df = occupation_df[occupation_df.sum(1) >1000000]

# %%
occupation_df.shape
# Out:
# (31, 2)

# %%
occupation_df.plot(kind='bar')

# %%
occupation_df.drop(['INFORMATION REQUESTED PER BEST EFFORTS'], axis=0, inplace=True)
occupation_df.plot(kind='barh',figsize=(10,12), cmap='seismic')

# %%
occupation_df.sort_values(by='Republican', inplace=True)
# Out:
# C:\Users\joshg\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
occupation_df
# Out:
# Party                 Democrat       Republican
# contbr_occupation
# NOT EMPLOYED        1709188.20     44819.730000
# WRITER              1084188.88    227928.410000
# PROFESSOR           2165071.08    296702.730000
# LAWYER              3160478.87    391224.320000
# TEACHER             1250969.15    463984.900000
# PARTNER              395759.50    842177.050000
# VICE PRESIDENT       325647.15    880162.260000
# INVESTMENTS          160480.00   1018667.640000
# STUDENT              628099.75   1073283.650000
# BANKER               224084.40   1259468.730000
# CHAIRMAN             496547.00   1296092.750000
# BUSINESS OWNER       449979.30   1323342.430000
# FINANCE              296031.40   1402514.910000
# MANAGER              762883.22   1444532.370000
# SALES                392886.91   1455464.910000
# CEO                 2073284.79   1618057.410000
# REAL ESTATE          528902.09   1625902.250000
# SELF-EMPLOYED        672393.40   1640252.540000
# ...

# %%
occupation_df.loc['CEO'] = occupation_df.loc['CEO'] + occupation_df.loc['C.E.O.']

occupation_df.drop('C.E.O.', inplace = True)
# Out:
# C:\Users\joshg\Anaconda3\lib\site-packages\pandas\core\indexing.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\joshg\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\joshg\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
occupation_df.plot(kind='barh',figsize=(10,12), cmap = 'seismic')
occupation_df.sort_values(by = 'Republican', inplace=True)
# Out:
# C:\Users\joshg\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
occupation_df
# Out:
# Party                 Democrat       Republican
# contbr_occupation
# NOT EMPLOYED        1709188.20     44819.730000
# WRITER              1084188.88    227928.410000
# PROFESSOR           2165071.08    296702.730000
# LAWYER              3160478.87    391224.320000
# TEACHER             1250969.15    463984.900000
# PARTNER              395759.50    842177.050000
# VICE PRESIDENT       325647.15    880162.260000
# INVESTMENTS          160480.00   1018667.640000
# STUDENT              628099.75   1073283.650000
# BANKER               224084.40   1259468.730000
# CHAIRMAN             496547.00   1296092.750000
# BUSINESS OWNER       449979.30   1323342.430000
# FINANCE              296031.40   1402514.910000
# MANAGER              762883.22   1444532.370000
# SALES                392886.91   1455464.910000
# REAL ESTATE          528902.09   1625902.250000
# SELF-EMPLOYED        672393.40   1640252.540000
# ENGINEER             951525.55   1818373.700000
# ...

# %%
occupation_df.plot(kind='barh',figsize=(10,12), cmap = 'seismic')
